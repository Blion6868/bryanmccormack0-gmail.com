# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read csv file from Kaggle
df = pd.read_csv(r"C:\Users\bryan\Desktop\Corona.csv")

# %%
#Dataset courtesy of Kaggle: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset

# %%
#inspect first 5 rows
df.head()
# Out:
#    id  case_in_country reporting date  \
# 0   1              NaN      1/20/2020
# 1   2              NaN      1/20/2020
# 2   3              NaN      1/21/2020
# 3   4              NaN      1/21/2020
# 4   5              NaN      1/21/2020
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0   China    male  66.0      1/3/2020                    0.0       1/11/2020
# 1   China  female  56.0     1/15/2020                    0.0       1/15/2020
# 2   China    male  46.0      1/4/2020                    0.0       1/17/2020
# 3   China  female  60.0           NaN                    NaN       1/19/2020
# 4   China    male  58.0           NaN                    NaN       1/14/2020
#
#   exposure_start exposure_end  visiting Wuhan  from Wuhan death recovered  \
# 0     12/29/2019     1/4/2020               1         0.0     0         0
# 1            NaN    1/12/2020               0         1.0     0         0
# 2            NaN     1/3/2020               0         1.0     0         0
# 3            NaN          NaN               1         0.0     0         0
# 4            NaN          NaN               0         0.0     0         0
#
#   symptom
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#general statistical overview of data
df.describe()
# Out:
#                 id  case_in_country         age  If_onset_approximated  \
# count  1085.000000       888.000000  843.000000             560.000000
# mean    543.000000        48.841216   49.483689               0.042857
# std     313.356825        78.853528   18.255334               0.202716
# min       1.000000         1.000000    0.250000               0.000000
# 25%     272.000000        11.000000   35.000000               0.000000
# 50%     543.000000        28.000000   51.000000               0.000000
# 75%     814.000000        67.250000   64.000000               0.000000
# max    1085.000000      1443.000000   96.000000               1.000000
#
#        visiting Wuhan   from Wuhan
# count     1085.000000  1081.000000
# mean         0.176959     0.144311
# std          0.381810     0.351567
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          0.000000     0.000000
# 75%          0.000000     0.000000
# max          1.000000     1.000000

# %%
df.replace(np.nan,0)
df.fillna(0)
# Out:
#         id  case_in_country reporting date  \
# 0        1              0.0      1/20/2020
# 1        2              0.0      1/20/2020
# 2        3              0.0      1/21/2020
# 3        4              0.0      1/21/2020
# 4        5              0.0      1/21/2020
# ...    ...              ...            ...
# 1080  1081              2.0      2/25/2020
# 1081  1082              1.0      2/24/2020
# 1082  1083              1.0      2/26/2020
# 1083  1084              1.0      2/25/2020
# 1084  1085              1.0      2/25/2020
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2     First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3     new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4     new confirmed imported COVID-19 pneumonia in T...              Tianjin
# ...                                                 ...                  ...
# 1080  new COVID-19 patient confirmed in Austria: 24,...            Innsbruck
# 1081  new COVID-19 patient confirmed in Afghanistan:...          Afghanistan
# 1082  new COVID-19 patient confirmed in Algeria: mal...              Algeria
# 1083  new COVID-19 patient confirmed in Croatia: mal...              Croatia
# 1084  new COVID-19 patient confirmed in Switzerland:...                 Bern
#
#           country  gender   age symptom_onset  If_onset_approximated  \
# 0           China    male  66.0      1/3/2020                    0.0
# 1           China  female  56.0     1/15/2020                    0.0
# 2           China    male  46.0      1/4/2020                    0.0
# 3           China  female  60.0             0                    0.0
# 4           China    male  58.0             0                    0.0
# ...           ...     ...   ...           ...                    ...
# 1080      Austria       0  24.0             0                    0.0
# 1081  Afghanistan       0  35.0             0                    0.0
# 1082      Algeria    male   0.0             0                    0.0
# 1083      Croatia    male   0.0             0                    0.0
# 1084  Switzerland    male  70.0     2/17/2020                    0.0
#
#      hosp_visit_date exposure_start exposure_end  visiting Wuhan  from Wuhan  \
# 0          1/11/2020     12/29/2019     1/4/2020               1         0.0
# 1          1/15/2020              0    1/12/2020               0         1.0
# 2          1/17/2020              0     1/3/2020               0         1.0
# 3          1/19/2020              0            0               1         0.0
# 4          1/14/2020              0            0               0         0.0
# ...              ...            ...          ...             ...         ...
# 1080               0              0            0               0         0.0
# 1081               0              0            0               0         0.0
# 1082               0              0    2/17/2020               0         0.0
# 1083               0      2/19/2020    2/21/2020               0         0.0
# 1084               0      2/15/2020    2/15/2020               0         0.0
#
#      death recovered symptom
# 0        0         0       0
# 1        0         0       0
# 2        0         0       0
# 3        0         0       0
# 4        0         0       0
# ...    ...       ...     ...
# 1080     0         0       0
# 1081     0         0       0
# 1082     0         0       0
# 1083     0         0       0
# 1084     0         0       0
#
# [1085 rows x 18 columns]

# %%
#turn symptom onset into dattime for easier analysis
df['symptom_onset'] = pd.to_datetime(df["symptom_onset"])
df['exposure_start'] = pd.to_datetime(df['exposure_start'])
df['exposure_end'] = pd.to_datetime(df['exposure_end'])

# %%
symptoms = df['symptom'].value_counts().nlargest(10)
symptoms
# Out:
# fever                         73
# fever, cough                  36
# cough                         14
# fever, malaise                 7
# fever, sore throat             6
# fever, cough, malaise          6
# cough, shortness of breath     3
# sore throat                    3
# fever, cough, sputum           3
# cough, fever                   3
# Name: symptom, dtype: int64

# %%
countries = df['country'].value_counts().nlargest(10)
countries
# Out:
# China          197
# Japan          190
# South Korea    114
# Hong Kong       94
# Singapore       93
# Germany         54
# Thailand        41
# France          39
# Taiwan          34
# Spain           34
# Name: country, dtype: int64

# %%
plt.hist(df['country'])
plt.xticks(rotation='vertical');

# %%
df['exposure_start'].value_counts()

df['exposure_start'].hist()
plt.xticks(rotation='vertical')
# Out:
# (array([737408., 737425., 737439., 737456., 737470.]),
#  <a list of 5 Text xticklabel objects>)

# %%
df['exposure_end'].value_counts()

df['exposure_end'].hist()
plt.xticks(rotation='vertical')
# Out:
# (array([737425., 737432., 737439., 737446., 737456., 737463., 737470.,
#         737477.]), <a list of 8 Text xticklabel objects>)

# %%
deaths = df.groupby('death').sum()
death

# %%
#correlation between all columns
df.corr()
# Out:
#                              id  case_in_country       age  \
# id                     1.000000        -0.214701 -0.033531
# case_in_country       -0.214701         1.000000  0.139974
# age                   -0.033531         0.139974  1.000000
# If_onset_approximated  0.192419        -0.246004 -0.026587
# visiting Wuhan        -0.201191        -0.179966 -0.186654
# from Wuhan            -0.277776        -0.156511  0.066846
#
#                        If_onset_approximated  visiting Wuhan  from Wuhan
# id                                  0.192419       -0.201191   -0.277776
# case_in_country                    -0.246004       -0.179966   -0.156511
# age                                -0.026587       -0.186654    0.066846
# If_onset_approximated               1.000000        0.218182    0.011592
# visiting Wuhan                      0.218182        1.000000   -0.182723
# from Wuhan                          0.011592       -0.182723    1.000000

# %%
#general statistical overview of data
df.describe()
# Out:
#                 id  case_in_country         age  If_onset_approximated  \
# count  1085.000000       888.000000  843.000000             560.000000
# mean    543.000000        48.841216   49.483689               0.042857
# std     313.356825        78.853528   18.255334               0.202716
# min       1.000000         1.000000    0.250000               0.000000
# 25%     272.000000        11.000000   35.000000               0.000000
# 50%     543.000000        28.000000   51.000000               0.000000
# 75%     814.000000        67.250000   64.000000               0.000000
# max    1085.000000      1443.000000   96.000000               1.000000
#
#        visiting Wuhan   from Wuhan
# count     1085.000000  1081.000000
# mean         0.176959     0.144311
# std          0.381810     0.351567
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          0.000000     0.000000
# 75%          0.000000     0.000000
# max          1.000000     1.000000

# %%
#create new column for the day of virus onset
df['Day'] = df['symptom_onset'].dt.day
df['Month'] = df['symptom_onset'].dt.month

# %%
df.head()
# Out:
#    id  case_in_country reporting date  \
# 0   1              NaN      1/20/2020
# 1   2              NaN      1/20/2020
# 2   3              NaN      1/21/2020
# 3   4              NaN      1/21/2020
# 4   5              NaN      1/21/2020
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0   China    male  66.0    2020-01-03                    0.0       1/11/2020
# 1   China  female  56.0    2020-01-15                    0.0       1/15/2020
# 2   China    male  46.0    2020-01-04                    0.0       1/17/2020
# 3   China  female  60.0           NaT                    NaN       1/19/2020
# 4   China    male  58.0           NaT                    NaN       1/14/2020
#
#   exposure_start exposure_end  visiting Wuhan  from Wuhan death recovered  \
# 0     2019-12-29   2020-01-04               1         0.0     0         0
# 1            NaT   2020-01-12               0         1.0     0         0
# 2            NaT   2020-01-03               0         1.0     0         0
# 3            NaT          NaT               1         0.0     0         0
# 4            NaT          NaT               0         0.0     0         0
#
#   symptom   Day  Month
# 0     NaN   3.0    1.0
# 1     NaN  15.0    1.0
# 2     NaN   4.0    1.0
# 3     NaN   NaN    NaN
# 4     NaN   NaN    NaN

# %%
#histogram of symptom onset
sns.catplot('Day', data=df, kind='count', size=12)
# Out:
# C:\Users\bryan\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#bar chart for gender count for virus
sns.catplot('gender', data=df, kind='count', size=10)

# %%
#plot for age by gender
fig = sns.FacetGrid(df,hue='gender',aspect=4, size=3)

fig.map(sns.kdeplot,'age',shade=True)

oldest = df['age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend();
